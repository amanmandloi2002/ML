# %% [markdown]
# The dataset for this example is available at:
#
# https://drive.google.com/open?id=1mVmGNx6cbfvRHC_DvF12ZL3wGLSHD9f_

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of LinearRegression_with_csv.ipynb CT07.ipynb')
dataset
# Out:
# Empty DataFrame
# Columns: [{"nbformat":4, nbformat_minor:0, metadata:{"colab":{"name":"Copy of LinearRegression_with_csv.ipynb CT07", provenance:[{"file_id":"1g2Q31NASGSHZMqItn6QGY_oeJULdAO0B", timestamp:1645771861807}]}, kernelspec:{"name":"python3", display_name:"Python 3"}, language_info:{"name":"python"}}, cells:[{"cell_type":"markdown", source:[""], metadata:{"id":"SPxhumkoU2dZ"}}, {"cell_type":"markdown", source:["The dataset for this example is available at:\n", \n, https://drive.google.com/open?id=1mVmGNx6cbfvRHC_DvF12ZL3wGLSHD9f_], metadata:{"id":"y4jDXvybU23q"}}, {"cell_type":"code", source:["from google.colab import drive\n", drive.mount('/content/drive')], metadata:{"colab":{"base_uri":"https://localhost:8080/"}, id:"3ndONWeOWBUG", executionInfo:{"status":"ok", timestamp:1645772187808, user_tz:-330, elapsed:38851, user:{"displayName":"PnA Services", photoUrl:"https://lh3.googleusercontent.com/a-/AOh14GixvDbaUBZZEIhVa4xnBHJ0009U_ItQnsFvZpTf4w=s64", userId:"11808584357635598740"}}, outputId:"da8dec9b-f960-416b-81a1-bf400ef3be28"}, execution_count:3, outputs:[{"output_type":"stream", name:"stdout", text:["Mounted at /content/drive\n"]}]}, {"cell_type":"code".1, source:["import pandas as pd\n", dataset = pd.read_csv\n, dataset], metadata:{"colab":{"base_uri":"https://localhost:8080/", height:362}, id:"mIXLV_bXU7Mo", executionInfo:{"status":"error", timestamp:1645772221956, user_tz:-330.1, elapsed:702, user:{"displayName":"PnA Services".1, photoUrl:"https://lh3.googleusercontent.com/a-/AOh14GixvDbaUBZZEIhVa4xnBHJ0009U_ItQnsFvZpTf4w=s64".1, userId:"11808584357635598740"}}.1, outputId:"1fa6ac49-c081-4879-8bbf-e50f7e632f5e"}, execution_count:5, outputs:[{"output_type":"error", ename:"FileNotFoundError", evalue:"ignored", traceback:["\u001b---------------------------------------------------------------------------\u001b", \u001bFileNotFoundError\u001b                         Traceback (most recent call last), \u001b<ipython-input-5-84bc2ba3bf52>\u001b in \u001b<module>\u001b()\u001b\n\u001b      1\u001b \u001bimport\u001b \u001bpandas\u001b \u001bas\u001b \u001bpd\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b----> 2\u001b \u001bdataset\u001b \u001b=\u001b \u001bpd\u001b\u001b.\u001b\u001bread_csv\u001b\u001b(\u001b\u001b'/content/drive/MyDrive/datasets (1)/petrol_consumption.csv'\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b\u001b      3\u001b \u001bdataset\u001b\u001b\u001b\u001b\u001b\u001b\n, \u001b/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py\u001b in \u001bwrapper\u001b(*args, **kwargs)\u001b\n\u001b    309\u001b                     \u001bstacklevel\u001b\u001b=\u001b\u001bstacklevel\u001b\u001b,\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    310\u001b                 )\n\u001b--> 311\u001b             \u001breturn\u001b \u001bfunc\u001b\u001b(\u001b\u001b*\u001b\u001bargs\u001b\u001b,\u001b \u001b**\u001b\u001bkwargs\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b\u001b    312\u001b \u001b\u001b\u001b\n\u001b    313\u001b         \u001breturn\u001b \u001bwrapper\u001b\u001b\u001b\u001b\u001b\u001b\n, \u001b/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py\u001b in \u001bread_csv\u001b(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)\u001b\n\u001b    584\u001b     \u001bkwds\u001b\u001b.\u001b\u001bupdate\u001b\u001b(\u001b\u001bkwds_defaults\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b ...
# Index: []
#
# [0 rows x 696 columns]

# %%
dataset.head()
# Out:
# Empty DataFrame
# Columns: [{"nbformat":4, nbformat_minor:0, metadata:{"colab":{"name":"Copy of LinearRegression_with_csv.ipynb CT07", provenance:[{"file_id":"1g2Q31NASGSHZMqItn6QGY_oeJULdAO0B", timestamp:1645771861807}]}, kernelspec:{"name":"python3", display_name:"Python 3"}, language_info:{"name":"python"}}, cells:[{"cell_type":"markdown", source:[""], metadata:{"id":"SPxhumkoU2dZ"}}, {"cell_type":"markdown", source:["The dataset for this example is available at:\n", \n, https://drive.google.com/open?id=1mVmGNx6cbfvRHC_DvF12ZL3wGLSHD9f_], metadata:{"id":"y4jDXvybU23q"}}, {"cell_type":"code", source:["from google.colab import drive\n", drive.mount('/content/drive')], metadata:{"colab":{"base_uri":"https://localhost:8080/"}, id:"3ndONWeOWBUG", executionInfo:{"status":"ok", timestamp:1645772187808, user_tz:-330, elapsed:38851, user:{"displayName":"PnA Services", photoUrl:"https://lh3.googleusercontent.com/a-/AOh14GixvDbaUBZZEIhVa4xnBHJ0009U_ItQnsFvZpTf4w=s64", userId:"11808584357635598740"}}, outputId:"da8dec9b-f960-416b-81a1-bf400ef3be28"}, execution_count:3, outputs:[{"output_type":"stream", name:"stdout", text:["Mounted at /content/drive\n"]}]}, {"cell_type":"code".1, source:["import pandas as pd\n", dataset = pd.read_csv\n, dataset], metadata:{"colab":{"base_uri":"https://localhost:8080/", height:362}, id:"mIXLV_bXU7Mo", executionInfo:{"status":"error", timestamp:1645772221956, user_tz:-330.1, elapsed:702, user:{"displayName":"PnA Services".1, photoUrl:"https://lh3.googleusercontent.com/a-/AOh14GixvDbaUBZZEIhVa4xnBHJ0009U_ItQnsFvZpTf4w=s64".1, userId:"11808584357635598740"}}.1, outputId:"1fa6ac49-c081-4879-8bbf-e50f7e632f5e"}, execution_count:5, outputs:[{"output_type":"error", ename:"FileNotFoundError", evalue:"ignored", traceback:["\u001b---------------------------------------------------------------------------\u001b", \u001bFileNotFoundError\u001b                         Traceback (most recent call last), \u001b<ipython-input-5-84bc2ba3bf52>\u001b in \u001b<module>\u001b()\u001b\n\u001b      1\u001b \u001bimport\u001b \u001bpandas\u001b \u001bas\u001b \u001bpd\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b----> 2\u001b \u001bdataset\u001b \u001b=\u001b \u001bpd\u001b\u001b.\u001b\u001bread_csv\u001b\u001b(\u001b\u001b'/content/drive/MyDrive/datasets (1)/petrol_consumption.csv'\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b\u001b      3\u001b \u001bdataset\u001b\u001b\u001b\u001b\u001b\u001b\n, \u001b/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py\u001b in \u001bwrapper\u001b(*args, **kwargs)\u001b\n\u001b    309\u001b                     \u001bstacklevel\u001b\u001b=\u001b\u001bstacklevel\u001b\u001b,\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    310\u001b                 )\n\u001b--> 311\u001b             \u001breturn\u001b \u001bfunc\u001b\u001b(\u001b\u001b*\u001b\u001bargs\u001b\u001b,\u001b \u001b**\u001b\u001bkwargs\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b\u001b    312\u001b \u001b\u001b\u001b\n\u001b    313\u001b         \u001breturn\u001b \u001bwrapper\u001b\u001b\u001b\u001b\u001b\u001b\n, \u001b/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py\u001b in \u001bread_csv\u001b(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)\u001b\n\u001b    584\u001b     \u001bkwds\u001b\u001b.\u001b\u001bupdate\u001b\u001b(\u001b\u001bkwds_defaults\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b ...
# Index: []
#
# [0 rows x 696 columns]

# %%
dataset.describe()
# Out:
#        {"nbformat":4  ... Root Mean Squared Error: 68.31064915215168\n]}]}]}
# count              0  ...                                                  0
# unique             0  ...                                                  0
# top              NaN  ...                                                NaN
# freq             NaN  ...                                                NaN
#
# [4 rows x 696 columns]

# %% [markdown]
# Preparing the Data
# The next step is to divide the data into attributes and labels as we did previously. However, unlike last time, this time around we are going to use column names for creating an attribute set and label. Execute the following script:

# %%
X = dataset[['Petrol_tax', 'Average_income', 'Paved_Highways',
       [/content/drive/MyDrive/Colab Notebooks/Copy of LinearRegression_with_csv.ipynb CT07.ipynb
    ]
y = dataset['Petrol_Consumption']
# Out:
#   File "<ipython-input-11-6d928945f1a2>", line 2
#     [/content/drive/MyDrive/Colab Notebooks/Copy of LinearRegression_with_csv.ipynb CT07.ipynb
#      ^
# SyntaxError: invalid syntax

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#     Actual   Predicted
# 29     534  469.391989
# 4      410  545.645464
# 26     577  589.668394
# 30     571  569.730413
# 32     577  649.774809
# 37     704  646.631164
# 34     487  511.608148
# 40     587  672.475177
# 7      467  502.074782
# 10     580  501.270734

# %%
from sklearn import metrics
import numpy as np
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 56.8222474789647
# Mean Squared Error: 4666.344787588362
# Root Mean Squared Error: 68.31064915215168
